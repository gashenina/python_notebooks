# %% [markdown]
# <h3><center>Что и кому должен аналитик?

# %% [markdown]
# <article id="back">
# #### __Навигация__
#
# <br><a href="#part1">1. Парсинг вакансий</a>
# <br><a href="#part2">2. Предобработка данных</a>
# <br><a href="#part3">3. Обзор данных</a>
# <br><a href="#part4">4. Как отличаются навыки, необходимые для каждой специальности?</a>
# <br><a href="#part5">5. В какую специальность легче всего зайти без релевантного опыта?</a>
# <br><a href="#part6">6. Как отличается заработная плата по специальностям?</a>

# %%
import pandas as pd
import numpy as np

import requests
from io import BytesIO 
import json
from time import sleep
from random import randint

pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# <a href="#back">В начало</a>
# <br>
# <br>
# <article id="part1"><h4>Код для парсинга URL вакансий по запросу *Аналитик, Продуктовый аналитик*

# %% [markdown]
# job_list = ['NAME:Аналитик',
#             'NAME:Продуктовый аналитик']
#
#
#
# pages = np.arange(0, 10, 1)
# vacancy_id = []
# salary_from = []
# salary_to = []
# employer = []
# name = []
# url = []
#
# for job in job_list:
#
#     for page in pages:
#         URL = 'https://api.hh.ru/vacancies'
#         params = {'text': job,
#                   'area': 1,
#                   'page': page,
#                   'per_page': 100
#                  }
#         req = requests.get(URL, params)
#         general_data = json.loads(req.content.decode())
#         sleep(randint(1,10))
#
#         for vacancy in general_data['items']:
#             vacancy_id.append(vacancy['id'])
#             employer.append(vacancy['employer']['name'])
#             name.append(vacancy['name'])
#             url.append(vacancy['url'])
#             if vacancy['salary'] is not None:
#                 salary_from.append(vacancy['salary']['from'])
#             else:
#                 salary_from.append(0)
#             if vacancy['salary'] is not None:
#                 salary_to.append(vacancy['salary']['to'])
#             else:
#                 salary_to.append(0)
#
# vacancy_data = pd.DataFrame(data=list(zip(vacancy_id,
#                                           employer,
#                                           salary_from,
#                                           salary_to,
#                                           url,
#                                           name)),
#                             columns=['vacancy_id',
#                                      'employer',
#                                      'salary_from',
#                                      'salary_to',
#                                      'url',
#                                      'name'])
#
# vacancy_data.to_csv('vacancy_data.csv', index = False, sep = ';')

# %% [markdown]
# <h4> Код для парсинга ключевых навыков и описания вакансий по URL на конкретные вакансии.

# %% [markdown]
# vacancy_id = []
# experience = []
# key_skills = []
# profarea_name = []
# description = []
#
# for item in vacancy_data['url']:
#     req = requests.get(item)
#     data = json.loads(req.content.decode())
#     #sleep(randint(1,10))
#     for skill in data['key_skills']:
#         vacancy_id.append(data['id'])
#         key_skills.append("".join(skill.values()))
#         experience.append(data['experience']['id'])
#         profarea_name.append(data['specializations'][0]['profarea_name'])
#         #description.append(data['description'])
#
# vacancy_detailed_data = pd.DataFrame(data=list(zip(vacancy_id,
#                                                    experience,
#                                                    key_skills,
#                                                    profarea_name,
#                                                    #description
#                                                   )),
#                                      columns=['vacancy_id',
#                                               'experience',
#                                               'key_skills',
#                                               'profarea_name',
#                                               #'description'
#                                              ])
#
# vacancy_detailed_data.to_csv('vacancy_detailed_data.csv', index = False, sep = ';')

# %% [markdown]
# Считываем данные с гугл диска.

# %%
spreadsheet_id = '1KAbXS2X28ulXLp_kf-ZMgzOO2wDqcuX_zzyZoCHdPtc'
file_name = 'https://docs.google.com/spreadsheets/d/{}/export?format=csv'.format(spreadsheet_id)
r = requests.get(file_name)
vacancy_data = pd.read_csv(BytesIO(r.content))

# %%
spreadsheet_id = '1koAOGhctTDT186bA6ukGQ4biAbm6LPnY_20sZLp47Vc'
file_name = 'https://docs.google.com/spreadsheets/d/{}/export?format=csv'.format(spreadsheet_id)
r = requests.get(file_name)
vacancy_detailed_data = pd.read_csv(BytesIO(r.content))

# %% [markdown]
# <a href="#back">В начало</a>
# <br>
# <br>
# <article id="part2"><h4>Предобработка названий вакансий, проф областей и навыков. Расчет доп параметров

# %% [markdown]
# Посмотрим топ вакансий по количеству объявлений.

# %%
(vacancy_data
 .groupby('name')
 .agg(count=('name','count'))
 .sort_values('count', ascending=False)
 .head(5)
 .reset_index()
)
# Out:
#                    name  count
# 0              Аналитик    175
# 1       Бизнес-аналитик    120
# 2  Продуктовый аналитик     55
# 3   Финансовый аналитик     44
# 4       Аналитик данных     32

# %% [markdown]
# Избавимся от слов, описывающих количество опыта (ведущий, младший и тд) или специфику конкретной вакансии (DWH, BI, SQL) и для всех названий, содержащих ключевое слово (системный, бизнес, продуктовый и тд) присвоим одинаковое короткое название.

# %%
trash_di = '|'.join(['ведущий', 'главный', 'middle', 'senior', 'junior', 'старший', 'младший', 'стажер', 'эксперт', 'данных', 'удаленно', 'менеджер', '-', 'dwh', 'bi', 'crm', 'sql', '\(', '\)'])

vacancy_data['name_short'] = (vacancy_data['name']
                              .str.lower()
                              .str.replace(trash_di, ' ')
                              .str.replace('web', 'веб')
                              .str.replace('digital', 'веб')
                              .str.strip()
                             )

vacancy_data.loc[vacancy_data['name_short'].str.contains('продуктовый аналитик'), 'name_short'] = 'продуктовый аналитик'
vacancy_data.loc[vacancy_data['name_short'].str.contains('аналитик данных'), 'name_short'] = 'аналитик'
vacancy_data.loc[vacancy_data['name_short'].str.contains('бизнес'), 'name_short'] = 'бизнес аналитик'
vacancy_data.loc[vacancy_data['name_short'].str.contains('маркет'), 'name_short'] = 'маркетолог аналитик'
vacancy_data.loc[vacancy_data['name_short'].str.contains('веб'), 'name_short'] = 'веб аналитик'

# %% [markdown]
# Добавим информацию о средней заработной плате: для тех вакансий, где задана одна из границ (от, до) возьмем ее в качестве среднего, а для вакансий с обеими границами посчитаем среднюю з.п.

# %%
vacancy_data['salary_from'] = vacancy_data['salary_from'].fillna(0)
vacancy_data['salary_to'] = vacancy_data['salary_to'].fillna(0)

zero_salary_from = (vacancy_data['salary_from'] == 0)
zero_salary_to = (vacancy_data['salary_to'] == 0)

vacancy_data.loc[zero_salary_from & zero_salary_to, 'avg_salary'] = 0
vacancy_data.loc[zero_salary_from & ~zero_salary_to, 'avg_salary'] = vacancy_data['salary_to']
vacancy_data.loc[~zero_salary_from & zero_salary_to, 'avg_salary'] = vacancy_data['salary_from']
vacancy_data.loc[~zero_salary_from & ~zero_salary_to, 'avg_salary'] = (vacancy_data['salary_from'] + vacancy_data['salary_to'])/2

# %% [markdown]
# Для удобства выделим короткие названия для основных проф областей.

# %%
vacancy_detailed_data['profarea_short'] = (vacancy_detailed_data['profarea_name']
                                           .str.replace('Информационные технологии, интернет, телеком', 'IT')
                                           .str.replace('Банки, инвестиции, лизинг', 'Банки')
                                           .str.replace('Маркетинг, реклама, PR', 'Маркетинг')
                                           .str.replace('Бухгалтерия, управленческий учет, финансы предприятия', 'Бухгалтерия')
                                           .str.replace('Начало карьеры, студенты', 'Internship')
                                          )

# %% [markdown]
# Приведем к нижнему регистру названия ключевых навыков.

# %%
vacancy_detailed_data['key_skills_short'] = vacancy_detailed_data['key_skills'].str.lower()

# %%
vacancy_detailed_data['key_skills_short'] 
(vacancy_detailed_data
 .groupby('key_skills')
 .agg(count=('key_skills','count'))
 .sort_values('count', ascending=False)
 .head(5)
 .reset_index()
)
# Out:
#                    key_skills  count
# 0                         SQL    308
# 1               MS PowerPoint    203
# 2               Бизнес-анализ    190
# 3                      MS SQL    142
# 4  Аналитические исследования    141

# %% [markdown]
# <a href="#back">В начало</a>
# <br>
# <br>
# <article id="part3"><h4>Сколько всего доступно (на 28.11.2020) вакансий по запросу *Аналитик, Продуктовый аналитик*?

# %%
print('Всего доступно {} вакансий, из них {} уникальных названий'.format(vacancy_data.shape[0], vacancy_data['name'].nunique()))
print('Всего доступно {} вакансий'.format(vacancy_data.shape[0]))
print('Всего доступно {} вакансии с перечислением навыков'.format(vacancy_detailed_data['vacancy_id'].nunique()))
print('Всего доступно {} вакансии с заполненным полем зп'.format(vacancy_data[vacancy_data['avg_salary'] > 0]['avg_salary'].nunique()))
# Out:
# Всего доступно 1178 вакансий, из них 514 уникальных названий
# Всего доступно 1178 вакансий
# Всего доступно 894 вакансии с перечислением навыков
# Всего доступно 63 вакансии с заполненным полем зп

# %% [markdown]
# Выделим топ-5 позиций по количеству объявлений.

# %%
top5 = (vacancy_data
        .groupby('name_short')
        .agg(count=('name_short','count'))
        .sort_values('count', ascending=False)
        .head(5)
        .reset_index()
       )
top5
# Out:
#              name_short  count
# 0              аналитик    297
# 1       бизнес аналитик    204
# 2  продуктовый аналитик    112
# 3   маркетолог аналитик     80
# 4          веб аналитик     50

# %% [markdown]
# Топ-5 позиций составляют 63% от всех вакансий, которые нам удалось получить.
#
# Выделим в отдельную таблицу данные о топ-5 позициях и далее будем работать с ней.

# %%
top5_data = (vacancy_data[vacancy_data['name_short'].isin(top5['name_short'])]
             .merge(vacancy_detailed_data,
                    on='vacancy_id',
                    how='inner')
            )

# %%
skills_pivot = (top5_data
                .pivot_table(index='key_skills_short',
                             columns='name_short',
                             values='vacancy_id',
                             aggfunc='count')
                .fillna(0)
               )

# %%
vacancy_detailed_data['key_skills_short'] 
(vacancy_detailed_data
 .groupby('key_skills')
 .agg(count=('key_skills','count'))
 .sort_values('count', ascending=False)
 .head(5)
 .reset_index()
)
# Out:
#                    key_skills  count
# 0                         SQL    308
# 1               MS PowerPoint    203
# 2               Бизнес-анализ    190
# 3                      MS SQL    142
# 4  Аналитические исследования    141

# %% [markdown]
# <a href="#back">В начало</a>
# <br>
# <br>
# <article id="part4"><h4>Как отличаются навыки, необходимые для каждой специальности?

# %%
skills_pivot = (top5_data
                .pivot_table(index='key_skills_short',
                             columns='name_short',
                             values='vacancy_id',
                             aggfunc='count')
                .fillna(0)
               )
skills_pivot = skills_pivot[skills_pivot.columns[::-1]]

top_skills_list = list(set(skills_pivot
                           .sort_values(by='аналитик', ascending=False)
                           .index[:3]
                   .append(skills_pivot
                           .sort_values(by='продуктовый аналитик', ascending=False)
                           .index[:3])
                   .append(skills_pivot
                           .sort_values(by='бизнес аналитик', ascending=False)
                           .index[:3])
                   .append(skills_pivot
                           .sort_values(by='маркетолог аналитик', ascending=False)
                           .index[:3])
                   .append(skills_pivot
                           .sort_values(by='веб аналитик', ascending=False)
                           .index[:3])
                  ))

(skills_pivot[skills_pivot.index.isin(top_skills_list)]
 .sort_values(by='продуктовый аналитик', ascending=False)
 .div(skills_pivot.sum(axis=0), axis=1)
 .style
 .format("{:.1%}")
 .background_gradient(cmap='Blues', axis=0)
)
# Out:
# <style  type="text/css" >
#     #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row0_col1 {
#             background-color:  #a8cee4;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row0_col2 {
#             background-color:  #61a7d2;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row0_col3 {
#             background-color:  #a5cde3;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row0_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row1_col0 {
#             background-color:  #2d7dbb;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row1_col1 {
#             background-color:  #d8e7f5;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row1_col2 {
#             background-color:  #e6f0f9;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row1_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row1_col4 {
#             background-color:  #cadef0;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row2_col0 {
#             background-color:  #68acd5;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row2_col1 {
#             background-color:  #e4eff9;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row2_col2 {
#             background-color:  #dfecf7;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row2_col3 {
#             background-color:  #e4eff9;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row2_col4 {
#             background-color:  #66abd4;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row3_col0 {
#             background-color:  #b2d2e8;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row3_col1 {
#             background-color:  #c6dbef;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row3_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row3_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row3_col4 {
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row4_col0 {
#             background-color:  #b5d4e9;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row4_col1 {
#             background-color:  #d8e7f5;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row4_col2 {
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row4_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row4_col4 {
#             background-color:  #9dcae1;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row5_col0 {
#             background-color:  #d6e6f4;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row5_col1 {
#             background-color:  #deebf7;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row5_col2 {
#             background-color:  #2474b7;
#             color:  #f1f1f1;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row5_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row5_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row6_col0 {
#             background-color:  #deebf7;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row6_col1 {
#             background-color:  #3181bd;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row6_col2 {
#             background-color:  #e6f0f9;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row6_col3 {
#             background-color:  #add0e6;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row6_col4 {
#             background-color:  #74b3d8;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row7_col0 {
#             background-color:  #e3eef9;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row7_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row7_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row7_col3 {
#             background-color:  #3f8fc5;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row7_col4 {
#             background-color:  #c4daee;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row8_col0 {
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row8_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row8_col2 {
#             background-color:  #dae8f6;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row8_col3 {
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row8_col4 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row9_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row9_col1 {
#             background-color:  #4191c6;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row9_col2 {
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row9_col3 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row9_col4 {
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row10_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row10_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row10_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row10_col3 {
#             background-color:  #99c7e0;
#             color:  #000000;
#         }    #T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78row10_col4 {
#             background-color:  #eaf3fb;
#             color:  #000000;
#         }</style><table id="T_95d9493a_31ad_11eb_a29c_3c15c2bb8e78" ><thead>    <tr>        <th class="index_name level0" >name_short</th>        <th class="col_heading level0 col0" >продуктовый аналитик</th>        <th class="col_heading level0 col1" >маркетолог аналитик</th>        <th class="col_heading level0 col2" >веб аналитик</th>        <th class="col_heading level0 col3" >бизнес аналитик</th>        <th class="col_heading level0 col4" >аналитик</th>    </tr>    <tr>        <th class="index_name level0" >key_skills_short</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ><

# %% [markdown]
# Видно, что ключевые навыки по специальностям отличаются: для Продуктового аналитика важны технические навыки (SQL, Python), для Маркетингового аналитика чаще упомниают маркетинговый анализ и PowerPoint, а для Веб аналитика GA и Я.Метрику.

# %%
(skills_pivot[['продуктовый аналитик']]
 .sort_values(by='продуктовый аналитик', ascending=False)
 .div(skills_pivot[['продуктовый аналитик']].sum(axis=0), axis=1)
 .head(11)
 .style
 .format("{:.1%}")
 .background_gradient(cmap='Blues', axis=0)
)
# Out:
# <style  type="text/css" >
#     #T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78row0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78row1_col0 {
#             background-color:  #3d8dc4;
#             color:  #000000;
#         }    #T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78row2_col0 {
#             background-color:  #92c4de;
#             color:  #000000;
#         }    #T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78row3_col0 {
#             background-color:  #d6e6f4;
#             color:  #000000;
#         }    #T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78row4_col0 {
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }    #T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78row5_col0 {
#             background-color:  #e4eff9;
#             color:  #000000;
#         }    #T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78row6_col0 {
#             background-color:  #e7f0fa;
#             color:  #000000;
#         }    #T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78row7_col0 {
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }    #T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78row8_col0 {
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }    #T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78row9_col0 {
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }    #T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78row10_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }</style><table id="T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78" ><thead>    <tr>        <th class="index_name level0" >name_short</th>        <th class="col_heading level0 col0" >продуктовый аналитик</th>    </tr>    <tr>        <th class="index_name level0" >key_skills_short</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78level0_row0" class="row_heading level0 row0" >sql</th>
#                         <td id="T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78row0_col0" class="data row0 col0" >11.4%</td>
#             </tr>
#             <tr>
#                         <th id="T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78level0_row1" class="row_heading level0 row1" >python</th>
#                         <td id="T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78row1_col0" class="data row1 col0" >8.0%</td>
#             </tr>
#             <tr>
#                         <th id="T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78level0_row2" class="row_heading level0 row2" >ms sql</th>
#                         <td id="T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78row2_col0" class="data row2 col0" >5.8%</td>
#             </tr>
#             <tr>
#                         <th id="T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78level0_row3" class="row_heading level0 row3" >google analytics</th>
#                         <td id="T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78row3_col0" class="data row3 col0" >3.6%</td>
#             </tr>
#             <tr>
#                         <th id="T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78level0_row4" class="row_heading level0 row4" >бизнес-анализ</th>
#                         <td id="T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78row4_col0" class="data row4 col0" >3.5%</td>
#             </tr>
#             <tr>
#                         <th id="T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78level0_row5" class="row_heading level0 row5" >анализ данных</th>
#                         <td id="T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78row5_col0" class="data row5 col0" >2.9%</td>
#             </tr>
#             <tr>
#                         <th id="T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78level0_row6" class="row_heading level0 row6" >аналитика</th>
#                         <td id="T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78row6_col0" class="data row6 col0" >2.8%</td>
#             </tr>
#             <tr>
#                         <th id="T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78level0_row7" class="row_heading level0 row7" >математическая статистика</th>
#                         <td id="T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78row7_col0" class="data row7 col0" >2.3%</td>
#             </tr>
#             <tr>
#                         <th id="T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78level0_row8" class="row_heading level0 row8" >аналитические исследования</th>
#                         <td id="T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78row8_col0" class="data row8 col0" >2.1%</td>
#             </tr>
#             <tr>
#                         <th id="T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78level0_row9" class="row_heading level0 row9" >статистический анализ</th>
#                         <td id="T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78row9_col0" class="data row9 col0" >2.1%</td>
#             </tr>
#             <tr>
#                         <th id="T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78level0_row10" class="row_heading level0 row10" >a/b тесты</th>
#                         <td id="T_95dfc3fa_31ad_11eb_9bf3_3c15c2bb8e78row10_col0" class="data row10 col0" >2.0%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Если более подробно посмотреть на специальность Продуктовый аналитик, окажется, что за техническими скиллами идут аналитические (анализ данных, аналитическое мышление, аналитические исследования) и знание статистики (математическая статистика, статистический анализ, a/b тесты).

# %% [markdown]
# <a href="#back">В начало</a>
# <br>
# <br>
# <article id="part5"><h4>В какую специальность легче всего зайти без опыта или с маленьким опытом?

# %%
experience_pivot = (top5_data
                    .pivot_table(index='experience',
                                 columns='name_short',
                                 values='vacancy_id',
                                 aggfunc='count')
                    .fillna(0)
               )
experience_pivot = experience_pivot[experience_pivot.columns[::-1]]

(experience_pivot
 .div(experience_pivot.sum(axis=0), axis=1)
 .style
 .format("{:.1%}")
 .background_gradient(cmap='Blues', axis=0)
)
# Out:
# <style  type="text/css" >
#     #T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row0_col0 {
#             background-color:  #084b93;
#             color:  #f1f1f1;
#         }    #T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row0_col1 {
#             background-color:  #4f9bcb;
#             color:  #000000;
#         }    #T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row0_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row0_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row0_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row1_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row1_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row1_col2 {
#             background-color:  #084e98;
#             color:  #f1f1f1;
#         }    #T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row1_col3 {
#             background-color:  #3181bd;
#             color:  #000000;
#         }    #T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row1_col4 {
#             background-color:  #97c6df;
#             color:  #000000;
#         }    #T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row2_col0 {
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }    #T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row2_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row2_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row2_col3 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row2_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row3_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row3_col1 {
#             background-color:  #eaf3fb;
#             color:  #000000;
#         }    #T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row3_col2 {
#             background-color:  #cfe1f2;
#             color:  #000000;
#         }    #T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row3_col3 {
#             background-color:  #eaf3fb;
#             color:  #000000;
#         }    #T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row3_col4 {
#             background-color:  #e2edf8;
#             color:  #000000;
#         }</style><table id="T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78" ><thead>    <tr>        <th class="index_name level0" >name_short</th>        <th class="col_heading level0 col0" >продуктовый аналитик</th>        <th class="col_heading level0 col1" >маркетолог аналитик</th>        <th class="col_heading level0 col2" >веб аналитик</th>        <th class="col_heading level0 col3" >бизнес аналитик</th>        <th class="col_heading level0 col4" >аналитик</th>    </tr>    <tr>        <th class="index_name level0" >experience</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78level0_row0" class="row_heading level0 row0" >between1And3</th>
#                         <td id="T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row0_col0" class="data row0 col0" >46.1%</td>
#                         <td id="T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row0_col1" class="data row0 col1" >32.3%</td>
#                         <td id="T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row0_col2" class="data row0 col2" >46.2%</td>
#                         <td id="T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row0_col3" class="data row0 col3" >55.9%</td>
#                         <td id="T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row0_col4" class="data row0 col4" >66.3%</td>
#             </tr>
#             <tr>
#                         <th id="T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78level0_row1" class="row_heading level0 row1" >between3And6</th>
#                         <td id="T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row1_col0" class="data row1 col0" >51.5%</td>
#                         <td id="T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row1_col1" class="data row1 col1" >50.1%</td>
#                         <td id="T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row1_col2" class="data row1 col2" >41.1%</td>
#                         <td id="T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row1_col3" class="data row1 col3" >38.7%</td>
#                         <td id="T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row1_col4" class="data row1 col4" >26.2%</td>
#             </tr>
#             <tr>
#                         <th id="T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78level0_row2" class="row_heading level0 row2" >moreThan6</th>
#                         <td id="T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row2_col0" class="data row2 col0" >2.0%</td>
#                         <td id="T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row2_col1" class="data row2 col1" >7.4%</td>
#                         <td id="T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row2_col2" class="data row2 col2" >1.8%</td>
#                         <td id="T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row2_col3" class="data row2 col3" >1.0%</td>
#                         <td id="T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row2_col4" class="data row2 col4" >0.2%</td>
#             </tr>
#             <tr>
#                         <th id="T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78level0_row3" class="row_heading level0 row3" >noExperience</th>
#                         <td id="T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row3_col0" class="data row3 col0" >0.3%</td>
#                         <td id="T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row3_col1" class="data row3 col1" >10.2%</td>
#                         <td id="T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row3_col2" class="data row3 col2" >10.9%</td>
#                         <td id="T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row3_col3" class="data row3 col3" >4.4%</td>
#                         <td id="T_95e5cc9e_31ad_11eb_9761_3c15c2bb8e78row3_col4" class="data row3 col4" >7.3%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# На позицию Продуктового аналитика чаще ожидают более опытных людей: более 51% вакансий хотят человека с 3-6 лет релевантного опыта.

# %% [markdown]
# <a href="#back">В начало</a>
# <br>
# <br>
# <article id="part6"><h4>Как отличается заработная плата по специальностям?

# %% [markdown]
# Вакансий с открытой мнформацией о заработной плате мало — всего 63. Тем не менее, посмотрим медианы зп по специальностям. Для адекватного сравнения, возьмем только вакансии с ожидаемым опытом "от 1го до 3х лет".

# %%
salary_pivot = (top5_data[(top5_data['avg_salary'] > 0) & (top5_data['experience'] == 'between1And3')]
                .groupby('name_short')
                .agg(median_salary=('avg_salary','median'))
                .reset_index()
                .sort_values(by='median_salary', ascending=False)
               )
salary_pivot
# Out:
#              name_short  median_salary
# 1       бизнес аналитик      140000.00
# 0              аналитик      100000.00
# 4  продуктовый аналитик      100000.00
# 3   маркетолог аналитик       70000.00
# 2          веб аналитик       60000.00

# %% [markdown]
# Бизнес аналитик в среднем может рассчитывать на 140т, продуктовый аналитик на 100т, а меньше всего готовы платить веб аналитику: 60т.
